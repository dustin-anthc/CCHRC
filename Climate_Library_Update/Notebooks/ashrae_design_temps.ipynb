# %%
import pandas as pd
import numpy as np
from random import sample
from pandas import *
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# Libraries from Alan
from __future__ import division
import json
import os
from matplotlib.pyplot import *

import requests
import tmy_ids

# Show Plots in the Notebook
# %matplotlib inline

# Make Plots larger
rcParams['figure.figsize']= (10, 6)
rcParams['font.size'] = 14

# %matplotlib inline

print 'Pandas version: ' + pd.__version__
# Out:
# Pandas version: 0.14.0

# %%
ashrae = pd.read_csv(r"C:\Users\dustin\Dropbox\AKWarm Documentation\02. Work\01. Task 2 - AKWarm library update\Climate Library\ASHRAE_Design_Conditions_V2.csv", header=0)
ashrae.head()
# Out:
#                    Station    Code Latitude Longitude  Elevation  \
# 0                 ADAK NAS  704540   51.88N   176.65W         16
# 1                ANCHORAGE  702730   61.17N   150.02W        115
# 2  ANCHORAGE MERRILL FIELD  702735   61.22N   149.85W        138
# 3                  ANNETTE  703980   55.02N   131.57W        112
# 4                   BARROW  700260   71.30N   156.77W         13
#
#    99% DB Temp (F)  99.6% DB Temp (F)  Mean Coincident Wind Speed 99.6% (mph)
# 0             23.0               20.1                                     4.5
# 1             -5.8              -10.7                                     4.0
# 2             -6.7              -11.0                                     1.6
# 3             19.4               14.5                                     8.1
# 4            -36.2              -41.3                                     7.6

# %%
tmy = pd.DataFrame(tmy_ids.tmy3_ids, columns=['tmy_id', 'station_name', 'tmy_class'])
tmy.head()
# Out:
#    tmy_id             station_name tmy_class
# 0  704540                 Adak NAS       III
# 1  701718                   Ambler        II
# 2  701625           Anaktuvuk Pass       III
# 3  702730        Anchorage Intl AP        II
# 4  702735  Anchorage Merrill Field        II

# %%
design_cond = ashrae.merge(tmy, left_on='Code', right_on='tmy_id', how='left')
design_cond
# Out:
#                      Station    Code Latitude Longitude  Elevation  \
# 0                   ADAK NAS  704540   51.88N   176.65W         16
# 1                  ANCHORAGE  702730   61.17N   150.02W        115
# 2    ANCHORAGE MERRILL FIELD  702735   61.22N   149.85W        138
# 3                    ANNETTE  703980   55.02N   131.57W        112
# 4                     BARROW  700260   71.30N   156.77W         13
# 5           BARTER IS WSO AP  700860   70.13N   143.63W         36
# 6                     BETHEL  702190   60.77N   161.80W        151
# 7                    BETTLES  701740   66.92N   151.52W        673
# 8                  BIG DELTA  702670   64.00N   145.72W       1273
# 9                   COLD BAY  703160   55.20N   162.72W         95
# 10                   CORDOVA  702960   60.50N   145.50W         39
# 11                 DEADHORSE  700637   70.20N   148.48W         75
# 12         DILLINGHAM (AMOS)  703210   59.05N   158.52W         95
# 13               EIELSON AFB  702650   64.67N   147.10W        548
# 14             ELMENDORF AFB  702720   61.25N   149.80W        213
# 15                 FAIRBANKS  702610   64.82N   147.87W        453
# 16        FIVE FINGER ISLAND  994080   57.27N   133.63W         23
# 17                FORT YUKON  701940   66.57N   145.27W        443
# 18  FT RICHARDSON/BRYANT APT  702700   61.27N   149.65W        377
# 19                   GULKANA  702710   62.15N   145.43W       1578
# 20                HOMER ARPT  703410   59.65N   151.48W         89
# 21              ILIAMNA ARPT  703400   59.75N   154.92W        184
# 22         JUNEAU INT`L ARPT  703810   58.35N   134.58W         10
# 23        KENAI MUNICIPAL AP  702590   60.58N   151.23W         85
# 24         KETCHIKAN INTL AP  703950   55.37N   131.72W         75
# 25               KING SALMON  703260   58.67N   156.63W         49
# 26                    KODIAK  703500   57.75N   152.32W        112
# 27                  KOTZEBUE  701330   66.87N   162.62W         16
# 28                   MCGRATH  702310   62.97N   155.62W        338
# 29      MIDDLETON ISLAND AUT  703430   59.45N   146.32W        118
# 30       NENANA MUNICIPAL AP  702600   64.55N   149.10W        358
# 31                      NOME  702000   64.50N   165.42W         23
# 32          NORTHWAY AIRPORT  702910   62.97N   141.93W       1713
# 33        PORT HEIDEN (AMOS)  703330   56.95N   158.62W         95
# 34       SAINT MARY`S (AWOS)  702005   62.07N   163.30W        312
# 35                    SEWARD  702770   60.12N   149.45W         59
# 36                    SHEMYA  704140   52.72N   174.12E         98
# 37         SITKA JAPONSKI AP  703710   57.05N   135.37W         13
# 38                  SOLDOTNA  702595   60.48N   151.03W        108
# 39               ST PAUL IS.  703080   57.15N   170.22W         23
# 40                 TALKEETNA  702510   62.28N   150.10W        344
# 41          UNALAKLEET FIELD  702070   63.88N   160.80W         13
# 42                VALDEZ WSO  702750   61.13N   146.35W         23
# 43                  WHITTIER  702757   60.77N   148.68W         30
# 44                  WRANGELL  703870   56.48N   132.37W         43
# 45                   YAKUTAT  703610   59.52N   139.67W         30
#
#     99% DB Temp (F)  99.6% DB Temp (F)  \
# 0              23.0               20.1
# 1              -5.8              -10.7
# 2              -6.7              -11.0
# 3              19.4               14.5
# 4             -36.2              -41.3
# 5             -39.5              -43.4
# 6             -23.8              -28.3
# 7             -46.7              -51.7
# 8             -42.7              -47.7
# 9              10.4                6.8
# 10              0.7               -4.2
# 11            -42.5              -47.0
# 12            -14.8              -20.4
# 13            -39.6              -44.1
# 14             -9.8              -15.2
# 15            -40.0              -44.5
# 16             21.6               18.0
# 17            -50.4              -54.8
# 18            -12.5              -18.6
# 19            -40.5              -45.6
# 20              3.7               -0.4
# 21            -16.1              -20.9
# 22              7.7                3.4
# 23            -16.8              -23.3
# 24             18.9               12.9
# 25            -19.3              -25.2
# 26             11.8                7.7
# 27            -31.2              -36.2
# 28            -42.7              -48.6
# 29             21.9               18.7
# 30            -44.0              -50.3
# 31            -25.4              -30.1
# 32            -46.7              -51.2
# 33             -3.3               -8.9
# 34            -21.3              -26.1
# 35              7.2                3.0
# 36             23.9               21.9
# 37             20.1               16.5
# 38            -20.7              -26.3
# 39              4.1               -0.2
# 40            -20.4              -27.4
# 41            -27.6              -33.3
# 42              7.3                4.1
# 43              8.8                4.5
# 44             14.0               10.0
# 45              4.5               -0.8
#
#     Mean Coincident Wind Speed 99.6% (mph)  tmy_id  \
# 0                                      4.5  704540
# 1                                      4.0  702730
# 2                                      1.6  702735
# 3                                      8.1  703980
# 4                                      7.6  700260
# 5                                      9.2     NaN
# 6                                      9.2  702190
# 7                                      1.3  701740
# 8                                      3.1  702670
# 9                                     15.4  703160
# 10                                     0.4  702960
# 11                                     9.6  700637
# 12                                     5.1  703210
# 13                                     1.3  702650
# 14                                     5.1  702720
# 15                                     1.1  702610
# 16                                    28.6     NaN
# 17                                     0.9  701940
# 18                                     1.3     NaN
# 19                                     3.4  702710
# 20                                     6.7  703410
# 21                                    10.5  703400
# 22                                     4.3  703810
# 23                                     2.2  702590
# 24                                     5.6  703950
# 25                                     6.3  703260
# 26                                    14.8  703500
# 27                                     6.3  701330
# 28                                     1.3  702310
# 29                                    15.7  703430
# 30                                     2.0  702600
# 31                                     3.1  702000
# 32                                     0.2  702910
# 33                                    14.3  703330
# 34                                     5.6  702005
# 35                                    20.8  702770
# 36                                    15.0  704140
# 37                                     6.9  703710
# 38                                     2.0  702595
# 39                                    17.7  703080
# 40                                     2.9  702510
# 41                                     3.6  702070
# 42                                    13.9  702750
# 43                                    27.1  702757
# 44                                     6.0  703870
# 45                                     1.8  703610
#
#                                station_name tmy_class
# 0                                  Adak NAS       III
# 1                         Anchorage Intl AP        II
# 2                   Anchorage Merrill Field        II
# 3                         Annette Island AP        II
# 4   Barrow W Post-W Rogers Arpt [NSA - ARM]        II
# 5                                       NaN       NaN
# 6                            Bethel Airport        II
# 7                             Bettles Field        II
# 8                       Big Delta Allen AAF        II
# 9                             Cold Bay Arpt        II
# 10                                  Cordova        II
# 11                                Deadhorse        II
# 12                        Dillingham (AMOS)        II
# 13                      Fairbanks/Eielson A        II
# 14                      Anchorage/Elmendorf        II
# 15                      Fairbanks Intl Arpt        II
# 16                                      NaN       NaN
# 17                               Fort Yukon       III
# 18                                      NaN       NaN
# 19               Gulkana Intermediate Field        II
# 20                               Homer Arpt        II
# 21                             Iliamna Arpt        II
# 22                         Juneau Intl Arpt        II
# 23                       Kenai Municipal AP        II
# 24                        Ketchikan Intl AP        II
# 25                         King Salmon Arpt        II
# 26                           Kodiak Airport        II
# 27             Kotzebue Ralph Wein Memorial        II
# 28                             McGrath Arpt        II
# 29                     Middleton Island Aut        II
# 30                      Nenana Municipal AP        II
# 31                      Nome Municipal Arpt        II
# 32                         Northway Airport        II
# 33                              Port Heiden        II
# 34                      Saint Mary`S (AWOS)        II
# 35                                   Seward        II
# 36                               Shemya AFB        II
# 37                        Sitka Japonski AP        II
# 38                                 Soldotna       III
# 39                      St Paul Island Arpt        II
# 40                     Talkeetna State Arpt        II
# 41                         Unalakleet Field       III
# 42                               Valdez Wso        II
# 43                                 Whittier        II
# 44                                 Wrangell        II
# 45                       Yakutat State Arpt        II

# %%
design_cond = design_cond[['tmy_id', 'station_name', '99% DB Temp (F)', 'Mean Coincident Wind Speed 99.6% (mph)', 'Latitude', 'Longitude']]
design_cond = design_cond.query("station_name == station_name")
design_cond
# Out:
#     tmy_id                             station_name  99% DB Temp (F)  \
# 0   704540                                 Adak NAS             23.0
# 1   702730                        Anchorage Intl AP             -5.8
# 2   702735                  Anchorage Merrill Field             -6.7
# 3   703980                        Annette Island AP             19.4
# 4   700260  Barrow W Post-W Rogers Arpt [NSA - ARM]            -36.2
# 6   702190                           Bethel Airport            -23.8
# 7   701740                            Bettles Field            -46.7
# 8   702670                      Big Delta Allen AAF            -42.7
# 9   703160                            Cold Bay Arpt             10.4
# 10  702960                                  Cordova              0.7
# 11  700637                                Deadhorse            -42.5
# 12  703210                        Dillingham (AMOS)            -14.8
# 13  702650                      Fairbanks/Eielson A            -39.6
# 14  702720                      Anchorage/Elmendorf             -9.8
# 15  702610                      Fairbanks Intl Arpt            -40.0
# 17  701940                               Fort Yukon            -50.4
# 19  702710               Gulkana Intermediate Field            -40.5
# 20  703410                               Homer Arpt              3.7
# 21  703400                             Iliamna Arpt            -16.1
# 22  703810                         Juneau Intl Arpt              7.7
# 23  702590                       Kenai Municipal AP            -16.8
# 24  703950                        Ketchikan Intl AP             18.9
# 25  703260                         King Salmon Arpt            -19.3
# 26  703500                           Kodiak Airport             11.8
# 27  701330             Kotzebue Ralph Wein Memorial            -31.2
# 28  702310                             McGrath Arpt            -42.7
# 29  703430                     Middleton Island Aut             21.9
# 30  702600                      Nenana Municipal AP            -44.0
# 31  702000                      Nome Municipal Arpt            -25.4
# 32  702910                         Northway Airport            -46.7
# 33  703330                              Port Heiden             -3.3
# 34  702005                      Saint Mary`S (AWOS)            -21.3
# 35  702770                                   Seward              7.2
# 36  704140                               Shemya AFB             23.9
# 37  703710                        Sitka Japonski AP             20.1
# 38  702595                                 Soldotna            -20.7
# 39  703080                      St Paul Island Arpt              4.1
# 40  702510                     Talkeetna State Arpt            -20.4
# 41  702070                         Unalakleet Field            -27.6
# 42  702750                               Valdez Wso              7.3
# 43  702757                                 Whittier              8.8
# 44  703870                                 Wrangell             14.0
# 45  703610                       Yakutat State Arpt              4.5
#
#     Mean Coincident Wind Speed 99.6% (mph) Latitude Longitude
# 0                                      4.5   51.88N   176.65W
# 1                                      4.0   61.17N   150.02W
# 2                                      1.6   61.22N   149.85W
# 3                                      8.1   55.02N   131.57W
# 4                                      7.6   71.30N   156.77W
# 6                                      9.2   60.77N   161.80W
# 7                                      1.3   66.92N   151.52W
# 8                                      3.1   64.00N   145.72W
# 9                                     15.4   55.20N   162.72W
# 10                                     0.4   60.50N   145.50W
# 11                                     9.6   70.20N   148.48W
# 12                                     5.1   59.05N   158.52W
# 13                                     1.3   64.67N   147.10W
# 14                                     5.1   61.25N   149.80W
# 15                                     1.1   64.82N   147.87W
# 17                                     0.9   66.57N   145.27W
# 19                                     3.4   62.15N   145.43W
# 20                                     6.7   59.65N   151.48W
# 21                                    10.5   59.75N   154.92W
# 22                                     4.3   58.35N   134.58W
# 23                                     2.2   60.58N   151.23W
# 24                                     5.6   55.37N   131.72W
# 25                                     6.3   58.67N   156.63W
# 26                                    14.8   57.75N   152.32W
# 27                                     6.3   66.87N   162.62W
# 28                                     1.3   62.97N   155.62W
# 29                                    15.7   59.45N   146.32W
# 30                                     2.0   64.55N   149.10W
# 31                                     3.1   64.50N   165.42W
# 32                                     0.2   62.97N   141.93W
# 33                                    14.3   56.95N   158.62W
# 34                                     5.6   62.07N   163.30W
# 35                                    20.8   60.12N   149.45W
# 36                                    15.0   52.72N   174.12E
# 37                                     6.9   57.05N   135.37W
# 38                                     2.0   60.48N   151.03W
# 39                                    17.7   57.15N   170.22W
# 40                                     2.9   62.28N   150.10W
# 41                                     3.6   63.88N   160.80W
# 42                                    13.9   61.13N   146.35W
# 43                                    27.1   60.77N   148.68W
# 44                                     6.0   56.48N   132.37W
# 45                                     1.8   59.52N   139.67W

# %%
design_cond.to_csv("ashrae_design_temps.csv")

# %%
tmy3_to_noaa = [
    (702730, 'Anchorage Intl AP', 'II', 'ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT AK US'),
    (703980, 'Annette Island AP', 'II',  'ANNETTE WEATHER SERVICE OFFICE AIRPORT AK US'),
    (700260, 'Barrow W Post-W Rogers Arpt [NSA - ARM]', 'II', 'BARROW W POST W ROGERS AIRPORT AK US'),
    (702190, 'Bethel Airport', 'II', 'BETHEL AIRPORT AK US'),
    (701740, 'Bettles Field', 'II', 'BETTLES AIRPORT AK US'),
    (702670, 'Big Delta Allen AAF', 'II', 'BIG DELTA AIRPORT AK US'),
    (703160, 'Cold Bay Arpt', 'II', 'COLD BAY AIRPORT AK US'),
    (702610, 'Fairbanks Intl Arpt', 'II', 'FAIRBANKS INTERNATIONAL AIRPORT AK US'),
    (702710, 'Gulkana Intermediate Field', 'II',  'GULKANA AIRPORT AK US'),
    (703410, 'Homer Arpt', 'II', 'HOMER AIRPORT AK US'),
    (703810, 'Juneau Intl Arpt', 'II', 'JUNEAU INTERNATIONAL AIRPORT AK US'),
    (703260, 'King Salmon Arpt', 'II', 'KING SALMON AIRPORT AK US'),
    (703500, 'Kodiak Airport', 'II',  'KODIAK AIRPORT AK US'),
    (701330, 'Kotzebue Ralph Wein Memorial', 'II', 'KOTZEBUE RALPH WEIN MEMORIAL AIRPORT AK '),
    (702310, 'McGrath Arpt', 'II', 'MCGRATH AIRPORT AK US'),
    (702000, 'Nome Municipal Arpt', 'II', 'NOME MUNICIPAL AIRPORT AK US'),
    (703080, 'St Paul Island Arpt', 'II', 'ST PAUL ISLAND AIRPORT AK US'),
    (702510, 'Talkeetna State Arpt', 'II', 'TALKEETNA AIRPORT AK US'),
    (703610, 'Yakutat State Arpt', 'II', 'YAKUTAT AIRPORT AK US'),
    (702986, 'Big River Lake', 'II', 'BIG RIVER LAKES AK US'),
    (702960, 'Cordova', 'II','CORDOVA M K SMITH AIRPORT AK US'),
    (704890, 'Dutch Harbor', 'II', 'DUTCH HARBOR AK US'),
    (702650, 'Fairbanks/Eielson A', 'II', 'EIELSON FIELD AK US'),
    
    #'Homer Arpt' is 7 miles away from Homer 8 NW.  The airport is on the coast and the NW site is inland.
    # Auke bay:  do we need this one?
    # Alyeska: don't think we need it
    # Cannery: middle of nowhere
    # College 5 NW, College, North Pole, University Experiment Station are unnecessary since we have Fairbanks station
    # Cooper landing: no nearby Tmy3
    # Eagle airport - nothing nearby
    # Glen alps : no station
    # Kitoi bay : nothing nearby, on Kodiak island
    # Kuparuk : 28 miles from deadhorse - use deadhorse tmy station?
    # little port walter not near anything
    # Matanuska Agricultural : 6 miles from Palmer Municipal TMY3 station
    (702740, 'Palmer Municipal', 'II', 'MATANUSKA AGRICULTURAL EXPERIMENT STATION AK US'),
    # main bay: not near anything
    # Tok : nothing nearby
    # White's crossing : no nearby tmy3
    # Nabesna: nothing close
    # Sutton: 10 miles from Palmer Municipal Airport tmy3 station
    # Port Alsworth: Nothing nearby
    (703400, 'Iliamna Arpt', 'II', 'ILIAMNA AIRPORT AK US'),
    (702590, 'Kenai Municipal AP', 'II', 'KENAI MUNICIPAL AIRPORT AK US'),
    (702910, 'Northway Airport', 'II', 'NORTHWAY AIRPORT AK US'),
    (702770, 'Seward', 'II', 'SEWARD AIRPORT AK US'),
    (703710, 'Sitka Japonski AP', 'II', 'SITKA AIRPORT AK US'),
    (701780, 'Tanana Ralph M Calhoun Mem AP', 'II', 'TANANA CALHOUN MEMORIAL AIRPORT AK US'),
    (702750, 'Valdez Wso', 'II', 'VALDEZ WEATHER SERVICE OFFICE AK US'),
    (703870, 'Wrangell', 'II', 'WRANGELL AIRPORT AK US')
]

# %%
tmy_to_noaa = pd.DataFrame(tmy3_to_noaa, columns=['tmy_ids', 'tmy_name', 'tmy_class', 'noaa_name'])
tmy_to_noaa
# Out:
#     tmy_ids                                 tmy_name tmy_class  \
# 0    702730                        Anchorage Intl AP        II
# 1    703980                        Annette Island AP        II
# 2    700260  Barrow W Post-W Rogers Arpt [NSA - ARM]        II
# 3    702190                           Bethel Airport        II
# 4    701740                            Bettles Field        II
# 5    702670                      Big Delta Allen AAF        II
# 6    703160                            Cold Bay Arpt        II
# 7    702610                      Fairbanks Intl Arpt        II
# 8    702710               Gulkana Intermediate Field        II
# 9    703410                               Homer Arpt        II
# 10   703810                         Juneau Intl Arpt        II
# 11   703260                         King Salmon Arpt        II
# 12   703500                           Kodiak Airport        II
# 13   701330             Kotzebue Ralph Wein Memorial        II
# 14   702310                             McGrath Arpt        II
# 15   702000                      Nome Municipal Arpt        II
# 16   703080                      St Paul Island Arpt        II
# 17   702510                     Talkeetna State Arpt        II
# 18   703610                       Yakutat State Arpt        II
# 19   702986                           Big River Lake        II
# 20   702960                                  Cordova        II
# 21   704890                             Dutch Harbor        II
# 22   702650                      Fairbanks/Eielson A        II
# 23   702740                         Palmer Municipal        II
# 24   703400                             Iliamna Arpt        II
# 25   702590                       Kenai Municipal AP        II
# 26   702910                         Northway Airport        II
# 27   702770                                   Seward        II
# 28   703710                        Sitka Japonski AP        II
# 29   701780            Tanana Ralph M Calhoun Mem AP        II
# 30   702750                               Valdez Wso        II
# 31   703870                                 Wrangell        II
#
#                                             noaa_name
# 0   ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT AK US
# 1        ANNETTE WEATHER SERVICE OFFICE AIRPORT AK US
# 2                BARROW W POST W ROGERS AIRPORT AK US
# 3                                BETHEL AIRPORT AK US
# 4                               BETTLES AIRPORT AK US
# 5                             BIG DELTA AIRPORT AK US
# 6                              COLD BAY AIRPORT AK US
# 7               FAIRBANKS INTERNATIONAL AIRPORT AK US
# 8                               GULKANA AIRPORT AK US
# 9                                 HOMER AIRPORT AK US
# 10                 JUNEAU INTERNATIONAL AIRPORT AK US
# 11                          KING SALMON AIRPORT AK US
# 12                               KODIAK AIRPORT AK US
# 13           KOTZEBUE RALPH WEIN MEMORIAL AIRPORT AK
# 14                              MCGRATH AIRPORT AK US
# 15                       NOME MUNICIPAL AIRPORT AK US
# 16                       ST PAUL ISLAND AIRPORT AK US
# 17                            TALKEETNA AIRPORT AK US
# 18                              YAKUTAT AIRPORT AK US
# 19                              BIG RIVER LAKES AK US
# 20                    CORDOVA M K SMITH AIRPORT AK US
# 21                                 DUTCH HARBOR AK US
# 22                                EIELSON FIELD AK US
# 23    MATANUSKA AGRICULTURAL EXPERIMENT STATION AK US
# 24                              ILIAMNA AIRPORT AK US
# 25                      KENAI MUNICIPAL AIRPORT AK US
# 26                             NORTHWAY AIRPORT AK US
# 27                               SEWARD AIRPORT AK US
# 28                                SITKA AIRPORT AK US
# 29              TANANA CALHOUN MEMORIAL AIRPORT AK US
# 30                VALDEZ WEATHER SERVICE OFFICE AK US
# 31                             WRANGELL AIRPORT AK US

# %%
ashrae_noaa_names = design_cond.merge(tmy_to_noaa, left_on='tmy_id', right_on='tmy_ids', how='left')
ashrae_noaa_names
# Out:
#     tmy_id                             station_name  99% DB Temp (F)  \
# 0   704540                                 Adak NAS             23.0
# 1   702730                        Anchorage Intl AP             -5.8
# 2   702735                  Anchorage Merrill Field             -6.7
# 3   703980                        Annette Island AP             19.4
# 4   700260  Barrow W Post-W Rogers Arpt [NSA - ARM]            -36.2
# 5   702190                           Bethel Airport            -23.8
# 6   701740                            Bettles Field            -46.7
# 7   702670                      Big Delta Allen AAF            -42.7
# 8   703160                            Cold Bay Arpt             10.4
# 9   702960                                  Cordova              0.7
# 10  700637                                Deadhorse            -42.5
# 11  703210                        Dillingham (AMOS)            -14.8
# 12  702650                      Fairbanks/Eielson A            -39.6
# 13  702720                      Anchorage/Elmendorf             -9.8
# 14  702610                      Fairbanks Intl Arpt            -40.0
# 15  701940                               Fort Yukon            -50.4
# 16  702710               Gulkana Intermediate Field            -40.5
# 17  703410                               Homer Arpt              3.7
# 18  703400                             Iliamna Arpt            -16.1
# 19  703810                         Juneau Intl Arpt              7.7
# 20  702590                       Kenai Municipal AP            -16.8
# 21  703950                        Ketchikan Intl AP             18.9
# 22  703260                         King Salmon Arpt            -19.3
# 23  703500                           Kodiak Airport             11.8
# 24  701330             Kotzebue Ralph Wein Memorial            -31.2
# 25  702310                             McGrath Arpt            -42.7
# 26  703430                     Middleton Island Aut             21.9
# 27  702600                      Nenana Municipal AP            -44.0
# 28  702000                      Nome Municipal Arpt            -25.4
# 29  702910                         Northway Airport            -46.7
# 30  703330                              Port Heiden             -3.3
# 31  702005                      Saint Mary`S (AWOS)            -21.3
# 32  702770                                   Seward              7.2
# 33  704140                               Shemya AFB             23.9
# 34  703710                        Sitka Japonski AP             20.1
# 35  702595                                 Soldotna            -20.7
# 36  703080                      St Paul Island Arpt              4.1
# 37  702510                     Talkeetna State Arpt            -20.4
# 38  702070                         Unalakleet Field            -27.6
# 39  702750                               Valdez Wso              7.3
# 40  702757                                 Whittier              8.8
# 41  703870                                 Wrangell             14.0
# 42  703610                       Yakutat State Arpt              4.5
#
#     Mean Coincident Wind Speed 99.6% (mph) Latitude Longitude  tmy_ids  \
# 0                                      4.5   51.88N   176.65W      NaN
# 1                                      4.0   61.17N   150.02W   702730
# 2                                      1.6   61.22N   149.85W      NaN
# 3                                      8.1   55.02N   131.57W   703980
# 4                                      7.6   71.30N   156.77W   700260
# 5                                      9.2   60.77N   161.80W   702190
# 6                                      1.3   66.92N   151.52W   701740
# 7                                      3.1   64.00N   145.72W   702670
# 8                                     15.4   55.20N   162.72W   703160
# 9                                      0.4   60.50N   145.50W   702960
# 10                                     9.6   70.20N   148.48W      NaN
# 11                                     5.1   59.05N   158.52W      NaN
# 12                                     1.3   64.67N   147.10W   702650
# 13                                     5.1   61.25N   149.80W      NaN
# 14                                     1.1   64.82N   147.87W   702610
# 15                                     0.9   66.57N   145.27W      NaN
# 16                                     3.4   62.15N   145.43W   702710
# 17                                     6.7   59.65N   151.48W   703410
# 18                                    10.5   59.75N   154.92W   703400
# 19                                     4.3   58.35N   134.58W   703810
# 20                                     2.2   60.58N   151.23W   702590
# 21                                     5.6   55.37N   131.72W      NaN
# 22                                     6.3   58.67N   156.63W   703260
# 23                                    14.8   57.75N   152.32W   703500
# 24                                     6.3   66.87N   162.62W   701330
# 25                                     1.3   62.97N   155.62W   702310
# 26                                    15.7   59.45N   146.32W      NaN
# 27                                     2.0   64.55N   149.10W      NaN
# 28                                     3.1   64.50N   165.42W   702000
# 29                                     0.2   62.97N   141.93W   702910
# 30                                    14.3   56.95N   158.62W      NaN
# 31                                     5.6   62.07N   163.30W      NaN
# 32                                    20.8   60.12N   149.45W   702770
# 33                                    15.0   52.72N   174.12E      NaN
# 34                                     6.9   57.05N   135.37W   703710
# 35                                     2.0   60.48N   151.03W      NaN
# 36                                    17.7   57.15N   170.22W   703080
# 37                                     2.9   62.28N   150.10W   702510
# 38                                     3.6   63.88N   160.80W      NaN
# 39                                    13.9   61.13N   146.35W   702750
# 40                                    27.1   60.77N   148.68W      NaN
# 41                                     6.0   56.48N   132.37W   703870
# 42                                     1.8   59.52N   139.67W   703610
#
#                                    tmy_name tmy_class  \
# 0                                       NaN       NaN
# 1                         Anchorage Intl AP        II
# 2                                       NaN       NaN
# 3                         Annette Island AP        II
# 4   Barrow W Post-W Rogers Arpt [NSA - ARM]        II
# 5                            Bethel Airport        II
# 6                             Bettles Field        II
# 7                       Big Delta Allen AAF        II
# 8                             Cold Bay Arpt        II
# 9                                   Cordova        II
# 10                                      NaN       NaN
# 11                                      NaN       NaN
# 12                      Fairbanks/Eielson A        II
# 13                                      NaN       NaN
# 14                      Fairbanks Intl Arpt        II
# 15                                      NaN       NaN
# 16               Gulkana Intermediate Field        II
# 17                               Homer Arpt        II
# 18                             Iliamna Arpt        II
# 19                         Juneau Intl Arpt        II
# 20                       Kenai Municipal AP        II
# 21                                      NaN       NaN
# 22                         King Salmon Arpt        II
# 23                           Kodiak Airport        II
# 24             Kotzebue Ralph Wein Memorial        II
# 25                             McGrath Arpt        II
# 26                                      NaN       NaN
# 27                                      NaN       NaN
# 28                      Nome Municipal Arpt        II
# 29                         Northway Airport        II
# 30                                      NaN       NaN
# 31                                      NaN       NaN
# 32                                   Seward        II
# 33                                      NaN       NaN
# 34                        Sitka Japonski AP        II
# 35                                      NaN       NaN
# 36                      St Paul Island Arpt        II
# 37                     Talkeetna State Arpt        II
# 38                                      NaN       NaN
# 39                               Valdez Wso        II
# 40                                      NaN       NaN
# 41                                 Wrangell        II
# 42                       Yakutat State Arpt        II
#
#                                             noaa_name
# 0                                                 NaN
# 1   ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT AK US
# 2                                                 NaN
# 3        ANNETTE WEATHER SERVICE OFFICE AIRPORT AK US
# 4                BARROW W POST W ROGERS AIRPORT AK US
# 5                                BETHEL AIRPORT AK US
# 6                               BETTLES AIRPORT AK US
# 7                             BIG DELTA AIRPORT AK US
# 8                              COLD BAY AIRPORT AK US
# 9                     CORDOVA M K SMITH AIRPORT AK US
# 10                                                NaN
# 11                                                NaN
# 12                                EIELSON FIELD AK US
# 13                                                NaN
# 14              FAIRBANKS INTERNATIONAL AIRPORT AK US
# 15                                                NaN
# 16                              GULKANA AIRPORT AK US
# 17                                HOMER AIRPORT AK US
# 18                              ILIAMNA AIRPORT AK US
# 19                 JUNEAU INTERNATIONAL AIRPORT AK US
# 20                      KENAI MUNICIPAL AIRPORT AK US
# 21                                                NaN
# 22                          KING SALMON AIRPORT AK US
# 23                               KODIAK AIRPORT AK US
# 24           KOTZEBUE RALPH WEIN MEMORIAL AIRPORT AK
# 25                              MCGRATH AIRPORT AK US
# 26                                                NaN
# 27                                                NaN
# 28                       NOME MUNICIPAL AIRPORT AK US
# 29                             NORTHWAY AIRPORT AK US
# 30                                                NaN
# 31                                                NaN
# 32                               SEWARD AIRPORT AK US
# 33                                                NaN
# 34                                SITKA AIRPORT AK US
# 35                                                NaN
# 36                       ST PAUL ISLAND AIRPORT AK US
# 37                            TALKEETNA AIRPORT AK US
# 38                                                NaN
# 39                VALDEZ WEATHER SERVICE OFFICE AK US
# 40                                                NaN
# 41                             WRANGELL AIRPORT AK US
# 42                              YAKUTAT AIRPORT AK US

# %%
stations52 = pd.read_csv("C:\Users\dustin\Documents\IPython Notebooks\stations52.csv", index_col=['index'])
stations52.head()
# Out:
#                                             station_name
# index
# 0                                          ALYESKA AK US
# 1      ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT AK US
# 2           ANNETTE WEATHER SERVICE OFFICE AIRPORT AK US
# 3                                         AUKE BAY AK US
# 4                   BARROW W POST W ROGERS AIRPORT AK US

# %%
ashrae_52 = stations52.merge(ashrae_noaa_names, left_on='station_name', right_on='noaa_name', how='left')
ashrae_52 = ashrae_52[['station_name_x', '99% DB Temp (F)', 'Mean Coincident Wind Speed 99.6% (mph)']]
ashrae_52 = ashrae_52.rename(columns = { 'station_name_x' : 'station_name', '99% DB Temp (F)' : 'heating_design_temp_F' , 
                                        'Mean Coincident Wind Speed 99.6% (mph)' : 'design_wind_speed (mph)'})
ashrae_52
# Out:
#                                          station_name  heating_design_temp_F  \
# 0                                       ALYESKA AK US                    NaN
# 1   ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT AK US                   -5.8
# 2        ANNETTE WEATHER SERVICE OFFICE AIRPORT AK US                   19.4
# 3                                      AUKE BAY AK US                    NaN
# 4                BARROW W POST W ROGERS AIRPORT AK US                  -36.2
# 5                                BETHEL AIRPORT AK US                  -23.8
# 6                               BETTLES AIRPORT AK US                  -46.7
# 7                             BIG DELTA AIRPORT AK US                  -42.7
# 8                               BIG RIVER LAKES AK US                    NaN
# 9                                 CANNERY CREEK AK US                    NaN
# 10                             COLD BAY AIRPORT AK US                   10.4
# 11                                 COLLEGE 5 NW AK US                    NaN
# 12                          COLLEGE OBSERVATORY AK US                    NaN
# 13                           COOPER LANDING 5 W AK US                    NaN
# 14                    CORDOVA M K SMITH AIRPORT AK US                    0.7
# 15                                 DUTCH HARBOR AK US                    NaN
# 16                                EAGLE AIRPORT AK US                    NaN
# 17                                EIELSON FIELD AK US                  -39.6
# 18              FAIRBANKS INTERNATIONAL AIRPORT AK US                  -40.0
# 19                                    GLEN ALPS AK US                    NaN
# 20                              GULKANA AIRPORT AK US                  -40.5
# 21                                   HOMER 8 NW AK US                    NaN
# 22                                HOMER AIRPORT AK US                    3.7
# 23                              ILIAMNA AIRPORT AK US                  -16.1
# 24                 JUNEAU INTERNATIONAL AIRPORT AK US                    7.7
# 25                      KENAI MUNICIPAL AIRPORT AK US                  -16.8
# 26                          KING SALMON AIRPORT AK US                  -19.3
# 27                                    KITOI BAY AK US                    NaN
# 28                               KODIAK AIRPORT AK US                   11.8
# 29           KOTZEBUE RALPH WEIN MEMORIAL AIRPORT AK                   -31.2
# 30                                      KUPARUK AK US                    NaN
# 31                           LITTLE PORT WALTER AK US                    NaN
# 32                                     MAIN BAY AK US                    NaN
# 33    MATANUSKA AGRICULTURAL EXPERIMENT STATION AK US                    NaN
# 34                              MCGRATH AIRPORT AK US                  -42.7
# 35                                      NABESNA AK US                    NaN
# 36                       NOME MUNICIPAL AIRPORT AK US                  -25.4
# 37                                   NORTH POLE AK US                    NaN
# 38                             NORTHWAY AIRPORT AK US                  -46.7
# 39                                PORT ALSWORTH AK US                    NaN
# 40                               SEWARD AIRPORT AK US                    7.2
# 41                                SITKA AIRPORT AK US                   20.1
# 42                       ST PAUL ISLAND AIRPORT AK US                    4.1
# 43                                   SUTTON 1 W AK US                    NaN
# 44                            TALKEETNA AIRPORT AK US                  -20.4
# 45              TANANA CALHOUN MEMORIAL AIRPORT AK US                    NaN
# 46                                          TOK AK US                    NaN
# 47                UNIVERSITY EXPERIMENT STATION AK US                    NaN
# 48                VALDEZ WEATHER SERVICE OFFICE AK US                    7.3
# 49                              WHITES CROSSING AK US                    NaN
# 50                             WRANGELL AIRPORT AK US                   14.0
# 51                              YAKUTAT AIRPORT AK US                    4.5
#
#     design_wind_speed (mph)
# 0                       NaN
# 1                       4.0
# 2                       8.1
# 3                       NaN
# 4                       7.6
# 5                       9.2
# 6                       1.3
# 7                       3.1
# 8                       NaN
# 9                       NaN
# 10                     15.4
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      0.4
# 15                      NaN
# 16                      NaN
# 17                      1.3
# 18                      1.1
# 19                      NaN
# 20                      3.4
# 21                      NaN
# 22                      6.7
# 23                     10.5
# 24                      4.3
# 25                      2.2
# 26                      6.3
# 27                      NaN
# 28                     14.8
# 29                      6.3
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      1.3
# 35                      NaN
# 36                      3.1
# 37                      NaN
# 38                      0.2
# 39                      NaN
# 40                     20.8
# 41                      6.9
# 42                     17.7
# 43                      NaN
# 44                      2.9
# 45                      NaN
# 46                      NaN
# 47                      NaN
# 48                     13.9
# 49                      NaN
# 50                      6.0
# 51                      1.8

# %%
count_df = ashrae_52.query("heating_design_temp_F == heating_design_temp_F")
count_df.count()
# Out:
# station_name               28
# heating_design_temp_F      28
# design_wind_speed (mph)    28
# dtype: int64

# %%
ashrae_52.to_csv("Design_Conditions_for_Main_Weather_Cities.csv")
